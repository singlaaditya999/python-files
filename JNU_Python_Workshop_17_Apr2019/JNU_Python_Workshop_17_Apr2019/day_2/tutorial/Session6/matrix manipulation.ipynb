# %%
def getMatrix(arr,col,rows):
    col=int(input("Enter colums:"))
    rows=int(input("Enter rows:"))
    arr=[[0]*col]*rows
    for i in range(0,rows):
        for j in range(0,col):
            print("Enter",i,",",j,"element")
            arr[i][j]=input()

def printMatrix(arr,col,rows):
    for row in arr:
        print(arr)

arr=[]
col=0
rows=0
getMatrix(arr,col,rows)
printMatrix(arr,col,rows)

# %%
class matrix:    
    def __init__(self,h=-1,w=-1):
        if h==-1:
            h=int(input("Enter no. of rows"))
        if w==-1:
            w=int(input("Enter no. of columns"))
        self._nrows = h
        self._ncols = w
        self._data = [0] * (self._nrows * self._ncols)
        
    def __str__(self):
        return "Matrix:" + str(self._nrows) + "by" + str(self._ncols)
    
    def setnrows(self,w):
        self._nrows=w
        self.reinit()
    
    def getnrows(self):
        return self._nrows
    
    def getncols(self):
        return self._ncols
    
    def getData(self,i,j):
        return self._data[i*self._nrows +j]
    
    def reinit(self):
        self._data=[0]*(self._nrows * self._ncols)
        
    def setncols(self,h):
        self._ncols=h
        self.reinit()
        
    def setValue(self,i,j,value):
        if i<self._nrows and j<self._ncols:
            self._data[i* self._nrows + j] =value
        else:
            raise Exception("Out of range")
        
    def setAllValue(self):
        for i in range(0,self._nrows):
            for j in range(0,self._ncols):
                print("Enter element",i,",",j)
                val=int(input())
                self.setValue(i,j,val)
                
    def magnitudeOfMatrix(self):
        
        
    def inv(self):
        if self._ncols !=self._nrows: raise Exception("Only square matrices are invertible")
        invertedMatrix = Matrix(self._ncols,self._nrows)
        invertedMatrix.setncols(self._ncols)
        invertedMatrix.setnrows(self._ncols)
        #invert
        return invertedMatrix
    
    def printMatrix(self):
        for i in range ( 0,self._nrows):
            for j in range(0,self._ncols):
                print(self._data[i*self._nrows +j])
                
class operations:
    def addition(matrix1,matrix2):
        row1=matrix1._nrows
        row2=matrix2._nrows
        col1=matrix1._ncols
        col2=matrix2._ncols
        if row1!=row2 and col1!=col2:
            print("Can not do addition")
            return 0
        else:
            ans=matrix(row1,col1)
            for i in range(0,row1):
                for j in range (0,col1):
                    ans.setValue(i,j,matrix1.getData(i,j)+matrix2.getData(i,j))
            return ans
    def 

m1=matrix ()
m1.setAllValue()
m2=matrix()
m2.setAllValue()
#print(m.__str__())

p=operations
ans=p.addition(m1,m2)
ans.printMatrix()
# Out:
# Enter no. of rows2
# Enter no. of columns2
# Enter element 0 , 0
# 1
# Enter element 0 , 1
# 2
# Enter element 1 , 0
# 3
# Enter element 1 , 1
# 4
# Enter no. of rows2
# Enter no. of columns2
# Enter element 0 , 0
# 1
# Enter element 0 , 1
# 2
# Enter element 1 , 0
# 3
# Enter element 1 , 1
# 4
# 2
# 4
# 6
# 8
